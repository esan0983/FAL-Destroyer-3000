# %% [markdown]
# # Data Cleaning

# %%
import pandas as pd
import os

# %%
df = pd.read_csv("../data/raw/anime_data.csv")
df.describe(include='all')
# Out:
#               mal_id         title    source     episodes  \
# count    7487.000000          7487      7487  7452.000000
# unique           NaN          7487        17          NaN
# top              NaN  Cowboy Bebop  Original          NaN
# freq             NaN             1      2849          NaN
# mean    28288.076933           NaN       NaN    39.773618
# std     18626.458621           NaN       NaN    84.249256
# min         1.000000           NaN       NaN     1.000000
# 25%      7176.500000           NaN       NaN    12.000000
# 50%     34295.000000           NaN       NaN    26.000000
# 75%     45820.500000           NaN       NaN    50.000000
# max     54803.000000           NaN       NaN  3000.000000
#
#                                                  synopsis         year  \
# count                                                5393  5554.000000
# unique                                               5362          NaN
# top     No synopsis has been added for this series yet...          NaN
# freq                                                   11          NaN
# mean                                                  NaN  2008.348758
# std                                                   NaN    13.014139
# min                                                   NaN  1961.000000
# 25%                                                   NaN  2003.000000
# 50%                                                   NaN  2012.000000
# 75%                                                   NaN  2018.000000
# max                                                   NaN  2026.000000
#
#         season producers genres studios demographics themes  \
# count     5554      7487   7487    7487         7487   7487
# unique       4      2935    488     733            8    692
# top     spring        []     []      []           []     []
# freq      1798      3107   1238    2359         3307   3058
# mean       NaN       NaN    NaN     NaN          NaN    NaN
# std        NaN       NaN    NaN     NaN          NaN    NaN
# min        NaN       NaN    NaN     NaN          NaN    NaN
# 25%        NaN       NaN    NaN     NaN          NaN    NaN
# 50%        NaN       NaN    NaN     NaN          NaN    NaN
# 75%        NaN       NaN    NaN     NaN          NaN    NaN
# max        NaN       NaN    NaN     NaN          NaN    NaN
#
#                            rating sequel      favorites        score  \
# count                        7421   7487    7487.000000  4865.000000
# unique                          5      2            NaN          NaN
# top     PG-13 - Teens 13 or older  False            NaN          NaN
# freq                         2866   5629            NaN          NaN
# mean                          NaN    NaN    1482.259516     6.855864
# std                           NaN    NaN    8908.089052     0.795549
# min                           NaN    NaN       0.000000     2.860000
# 25%                           NaN    NaN       0.000000     6.340000
# 50%                           NaN    NaN       9.000000     6.860000
# 75%                           NaN    NaN     252.500000     7.380000
# max                           NaN    NaN  255136.000000     9.250000
#
#                   wc        dropped         forum
# count   7.487000e+03    7487.000000   7487.000000
# unique           NaN            NaN           NaN
# top              NaN            NaN           NaN
# freq             NaN            NaN           NaN
# mean    8.132098e+04    4523.750234    403.558835
# std     2.523037e+05   11405.878933    905.642125
# min     0.000000e+00       0.000000      0.000000
# 25%     7.100000e+01      52.000000      0.000000
# 50%     1.932000e+03     303.000000      0.000000
# 75%     4.141800e+04    4036.500000    423.000000
# max     4.095607e+06  247257.000000  16318.000000

# %% [markdown]
# Let's remove duplicates.

# %%
df2 = df.drop_duplicates()
df2.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7487 entries, 0 to 7486
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mal_id        7487 non-null   int64
#  1   title         7487 non-null   str
#  2   source        7487 non-null   str
#  3   episodes      7452 non-null   float64
#  4   synopsis      5393 non-null   str
#  5   year          5554 non-null   float64
#  6   season        5554 non-null   str
#  7   producers     7487 non-null   str
#  8   genres        7487 non-null   str
#  9   studios       7487 non-null   str
#  10  demographics  7487 non-null   str
#  11  themes        7487 non-null   str
#  12  rating        7421 non-null   str
#  13  sequel        7487 non-null   bool
#  14  favorites     7487 non-null   int64
#  15  score         4865 non-null   float64
#  16  wc            7487 non-null   int64
#  17  dropped       7487 non-null   int64
#  18  forum         7487 non-null   int64
# dtypes: bool(1), float64(3), int64(5), str(10)
# memory usage: 1.0 MB

# %% [markdown]
# ## Ongoing Anime
#
# Tenrai API most likely has an "ongoing" variable, I just forgot to include it and I don't wanna redo 3 days of API calling. Luckily, if the episode count is null, then it's currently ongoing.

# %%
df3 = df2[~df2['episodes'].isna()]
df3.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 7452 entries, 0 to 7486
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mal_id        7452 non-null   int64
#  1   title         7452 non-null   str
#  2   source        7452 non-null   str
#  3   episodes      7452 non-null   float64
#  4   synopsis      5361 non-null   str
#  5   year          5525 non-null   float64
#  6   season        5525 non-null   str
#  7   producers     7452 non-null   str
#  8   genres        7452 non-null   str
#  9   studios       7452 non-null   str
#  10  demographics  7452 non-null   str
#  11  themes        7452 non-null   str
#  12  rating        7388 non-null   str
#  13  sequel        7452 non-null   bool
#  14  favorites     7452 non-null   int64
#  15  score         4847 non-null   float64
#  16  wc            7452 non-null   int64
#  17  dropped       7452 non-null   int64
#  18  forum         7452 non-null   int64
# dtypes: bool(1), float64(3), int64(5), str(10)
# memory usage: 1.1 MB

# %% [markdown]
# ## Scoreless Anime
#
# According to research, animes that have an N/A score are usually the obsucre and niche ones, or those super short ones that are only broadcast regionally. We will confirm this by looking at the wc and favorites count as well.

# %%
temp_df = df3[df3['score'].isna()]
temp_df['favorites'].describe()
# Out:
# count    2605.000000
# mean        0.224184
# std         5.001577
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max       254.000000
# Name: favorites, dtype: float64

# %%
temp_df['wc'].describe()
# Out:
# count    2605.000000
# mean       75.494434
# std        66.017998
# min         2.000000
# 25%        38.000000
# 50%        43.000000
# 75%        82.000000
# max       576.000000
# Name: wc, dtype: float64

# %% [markdown]
# Looking at the means, the scoreless anime really are irrelevant, and would just cloud statistical analysis and predictive modeling. Let's remove them.

# %%
df4 = df3[~df3['score'].isna()]
df4.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 4847 entries, 0 to 7486
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mal_id        4847 non-null   int64
#  1   title         4847 non-null   str
#  2   source        4847 non-null   str
#  3   episodes      4847 non-null   float64
#  4   synopsis      4811 non-null   str
#  5   year          4804 non-null   float64
#  6   season        4804 non-null   str
#  7   producers     4847 non-null   str
#  8   genres        4847 non-null   str
#  9   studios       4847 non-null   str
#  10  demographics  4847 non-null   str
#  11  themes        4847 non-null   str
#  12  rating        4814 non-null   str
#  13  sequel        4847 non-null   bool
#  14  favorites     4847 non-null   int64
#  15  score         4847 non-null   float64
#  16  wc            4847 non-null   int64
#  17  dropped       4847 non-null   int64
#  18  forum         4847 non-null   int64
# dtypes: bool(1), float64(3), int64(5), str(10)
# memory usage: 724.2 KB

# %% [markdown]
# Since I'm taking z-scores against cohort competitors (season & year), I would like to remove the 43 anime that do not have a year nor season.

# %%
df5 = df4.dropna(subset=['year', 'season'])
df5.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 4804 entries, 0 to 7486
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mal_id        4804 non-null   int64
#  1   title         4804 non-null   str
#  2   source        4804 non-null   str
#  3   episodes      4804 non-null   float64
#  4   synopsis      4770 non-null   str
#  5   year          4804 non-null   float64
#  6   season        4804 non-null   str
#  7   producers     4804 non-null   str
#  8   genres        4804 non-null   str
#  9   studios       4804 non-null   str
#  10  demographics  4804 non-null   str
#  11  themes        4804 non-null   str
#  12  rating        4774 non-null   str
#  13  sequel        4804 non-null   bool
#  14  favorites     4804 non-null   int64
#  15  score         4804 non-null   float64
#  16  wc            4804 non-null   int64
#  17  dropped       4804 non-null   int64
#  18  forum         4804 non-null   int64
# dtypes: bool(1), float64(3), int64(5), str(10)
# memory usage: 717.8 KB

# %% [markdown]
# No synopsis should be fine. My justification is that shows with no synopsis might be boring for users who look at MAL. However, categorizing by age rating is important: we need to know if restrictive shows have lower metrics.

# %%
df6 = df5[~df5['rating'].isna()]
df6.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 4774 entries, 0 to 7486
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mal_id        4774 non-null   int64
#  1   title         4774 non-null   str
#  2   source        4774 non-null   str
#  3   episodes      4774 non-null   float64
#  4   synopsis      4741 non-null   str
#  5   year          4774 non-null   float64
#  6   season        4774 non-null   str
#  7   producers     4774 non-null   str
#  8   genres        4774 non-null   str
#  9   studios       4774 non-null   str
#  10  demographics  4774 non-null   str
#  11  themes        4774 non-null   str
#  12  rating        4774 non-null   str
#  13  sequel        4774 non-null   bool
#  14  favorites     4774 non-null   int64
#  15  score         4774 non-null   float64
#  16  wc            4774 non-null   int64
#  17  dropped       4774 non-null   int64
#  18  forum         4774 non-null   int64
# dtypes: bool(1), float64(3), int64(5), str(10)
# memory usage: 713.3 KB

# %% [markdown]
# For now, we can save this.

# %%
folder_path = "../data/processed"
file_name = "anime_data_1.csv"
full_path = os.path.join(folder_path, file_name)
df6.to_csv(full_path, index=False)
print(f"File successfully saved to: {full_path}")
# Out:
# File successfully saved to: ../data/processed\anime_data_1.csv
